# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set()

# %%
cd F:\Fingertips\6_ML\End2End_project
# Out:
# F:\Fingertips\6_ML\End2End_project

# %%
df=pd.read_csv("churn_telecom.csv")
df.head(10)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
# 8    WV             141        415                Yes             Yes
# 9    RI              74        415                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# ...

# %%
df.shape
# Out:
# (2666, 20)

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   2666 non-null   object
#  1   Account length          2666 non-null   int64
#  2   Area code               2666 non-null   int64
#  3   International plan      2666 non-null   object
#  4   Voice mail plan         2666 non-null   object
#  5   Number vmail messages   2666 non-null   int64
#  6   Total day minutes       2666 non-null   float64
#  7   Total day calls         2666 non-null   int64
#  8   Total day charge        2666 non-null   float64
#  9   Total eve minutes       2666 non-null   float64
#  10  Total eve calls         2666 non-null   int64
#  11  Total eve charge        2666 non-null   float64
#  12  Total night minutes     2666 non-null   float64
#  13  Total night calls       2666 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     2666.000000  2666.000000            2666.000000         2666.00000
# mean       100.620405   437.438860               8.021755          179.48162
# std         39.563974    42.521018              13.612277           54.21035
# min          1.000000   408.000000               0.000000            0.00000
# 25%         73.000000   408.000000               0.000000          143.40000
# 50%        100.000000   415.000000               0.000000          179.95000
# 75%        127.000000   510.000000              19.000000          215.90000
# max        243.000000   510.000000              50.000000          350.80000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      2666.000000       2666.000000        2666.000000      2666.000000
# mean        100.310203         30.512404         200.386159       100.023631
# ...

# %%
df.isna().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

lblenc = LabelEncoder()

df['International plan'] = lblenc.fit_transform(df['International plan'])
df['Voice mail plan'] = lblenc.fit_transform(df['Voice mail plan'])
df['Churn'] = lblenc.fit_transform(df['Churn'])

# %%
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415                   0                1
# 1    OH             107        415                   0                1
# 2    NJ             137        415                   0                0
# 3    OH              84        408                   1                0
# 4    OK              75        415                   1                0
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
#who have international plan
sns.countplot('International plan',data=df)
# Out:
# <AxesSubplot:xlabel='International plan', ylabel='count'>

# %%
#who have voice mail plan
sns.countplot('Voice mail plan',data=df)
# Out:
# <AxesSubplot:xlabel='Voice mail plan', ylabel='count'>

# %%
#total day calls
sns.countplot('Total day calls',data=df)
# Out:
# <AxesSubplot:xlabel='Total day calls', ylabel='count'>

# %%
sns.distplot(df["Total day calls"])
# Out:
# <AxesSubplot:xlabel='Total day calls', ylabel='Density'>

# %%
sns.distplot(df["Total day charge"])
# Out:
# <AxesSubplot:xlabel='Total day charge', ylabel='Density'>

# %%
sns.catplot('Total day charge',data=df)

# %%
df["Churn"].value_counts()
# Out:
# 0    2278
# 1     388
# Name: Churn, dtype: int64

# %%
df["Churn"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Churn'>

# %%
plt.figure(figsize=(20,10))
plt.scatter(df["Total day calls"],df["Total day charge"])
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.scatter(df["Total day calls"],df["Total eve calls"])
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.scatter(df["Total eve calls"],df["Total night calls"])
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.scatter(df["Total day calls"],df["Total night calls"])
plt.show()

# %%
box_plot_data=[df["Total day minutes"],df["Churn"]]
plt.figure(figsize=(20,10))
plt.boxplot(box_plot_data)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x="Total day minutes", y="Churn", data=df)
# Out:
# <AxesSubplot:xlabel='Total day minutes', ylabel='Churn'>

# %%
box_plot_data=[df["Total day charge"],df["Churn"]]
plt.figure(figsize=(20,10))
plt.boxplot(box_plot_data)
plt.show()

# %%
df.drop(["State"],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Account length          2666 non-null   int64
#  1   Area code               2666 non-null   int64
#  2   International plan      2666 non-null   int32
#  3   Voice mail plan         2666 non-null   int32
#  4   Number vmail messages   2666 non-null   int64
#  5   Total day minutes       2666 non-null   float64
#  6   Total day calls         2666 non-null   int64
#  7   Total day charge        2666 non-null   float64
#  8   Total eve minutes       2666 non-null   float64
#  9   Total eve calls         2666 non-null   int64
#  10  Total eve charge        2666 non-null   float64
#  11  Total night minutes     2666 non-null   float64
#  12  Total night calls       2666 non-null   int64
#  13  Total night charge      2666 non-null   float64
# ...

# %%
df.head(10)
# Out:
#    Account length  Area code  International plan  Voice mail plan  \
# 0             128        415                   0                1
# 1             107        415                   0                1
# 2             137        415                   0                0
# 3              84        408                   1                0
# 4              75        415                   1                0
# 5             118        510                   1                0
# 6             121        510                   0                1
# 7             147        415                   1                0
# 8             141        415                   1                1
# 9              74        415                   0                0
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# ...

# %%
from sklearn.preprocessing import StandardScaler
std_scal = StandardScaler()

# %%
df[['Total day minutes','Total day calls']]= std_scal.fit_transform(df[['Total day minutes','Total day calls']])
df[['Total day charge','Total eve minutes']]=std_scal.fit_transform(df[['Total day charge','Total eve minutes']])
df[['Total eve calls','Total eve charge']]= std_scal.fit_transform(df[['Total eve calls','Total eve charge']])
df[['Total night minutes','Total night calls']]= std_scal.fit_transform(df[['Total night minutes','Total night calls']])
df[['Total night charge','Total intl minutes']]= std_scal.fit_transform(df[['Total night charge','Total intl minutes']])
df[['Total intl calls','Total intl charge']]= std_scal.fit_transform(df[['Total intl calls','Total intl charge']])

df.head()
# Out:
#    Account length  Area code  International plan  Voice mail plan  \
# 0             128        415                   0                1
# 1             107        415                   0                1
# 2             137        415                   0                0
# 3              84        408                   1                0
# 4              75        415                   1                0
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25           1.579670         0.484868
# 1                     26          -0.329918         1.135375
# 2                      0           1.179302         0.685024
# 3                      0           2.212509        -1.466653
# 4                      0          -0.235822         0.634985
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0          1.579942          -0.058619        -0.050781         -0.058445
# ...

# %%
plt.figure(figsize=(20,20))
g=sns.heatmap(df.corr(),annot=True,cmap="RdYlGn")
plt.show()

# %% [markdown]
# # feature selection

# %%
x = df.drop('Churn',axis=1)
y = df.Churn

# %%
from sklearn.ensemble import ExtraTreesRegressor

selection = ExtraTreesRegressor()
selection.fit(x, y)
# Out:
# ExtraTreesRegressor()

# %%
print(selection.feature_importances_)
# Out:
# [0.02237909 0.01552444 0.07823984 0.04211396 0.01297866 0.12314146
#  0.02423743 0.1173503  0.06799343 0.02087113 0.06395147 0.03336442
#  0.02280963 0.03409097 0.05057649 0.09014693 0.04811138 0.13211895]

# %%
plt.figure(figsize = (12,8))
df_feat = pd.Series(selection.feature_importances_, index=x.columns)
df_feat.nlargest(7).plot(kind='barh')
plt.show()

# %%
new_df =df[['Customer service calls','Total day charge','Total day minutes','Total intl calls','International plan','Total eve minutes','Total eve charge','Churn']]
new_df.head()
# Out:
#    Customer service calls  Total day charge  Total day minutes  \
# 0                       1          1.579942           1.579670
# 1                       1         -0.330194          -0.329918
# 2                       0          1.179465           1.179302
# 3                       2          2.212675           2.212509
# 4                       3         -0.235772          -0.235822
#
#    Total intl calls  International plan  Total eve minutes  Total eve charge  \
# 0         -0.597527                   0          -0.058619         -0.058445
# 1         -0.597527                   0          -0.095916         -0.095397
# 2          0.216894                   0          -1.554439         -1.554963
# 3          1.031314                   1          -2.718509         -2.718922
# 4         -0.597527                   1          -1.022461         -1.021482
#
#    Churn
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
X = new_df.drop('Churn',axis=1)
Y = new_df.Churn

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, train_size=0.8, random_state = 9)
print("Dimension of X_train:", X_train.shape)
print("Dimension of X_test:", X_test.shape)
# Out:
# Dimension of X_train: (2132, 7)
# Dimension of X_test: (534, 7)

# %%
from sklearn.linear_model import LogisticRegression

log = LogisticRegression()
log.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
log.score(X_test,Y_test)
# Out:
# 0.8857677902621723

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,f1_score

Y_pred = log.predict(X_test)

# %%
con_mat=confusion_matrix(Y_pred,Y_test)
con_mat
# Out:
# array([[457,  51],
#        [ 10,  16]], dtype=int64)

# %%
cm_matrix = pd.DataFrame(data=con_mat, columns=['Actual Positive:1', 'Actual Negative:0'], 
                                 index=['Predict Positive:1', 'Predict Negative:0'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
print("Accuracy:",accuracy_score(Y_test, Y_pred))
print("Precision:",precision_score(Y_test, Y_pred))
print("Recall:",recall_score(Y_test, Y_pred))
print("f1_score:",f1_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.8857677902621723
# Precision: 0.6153846153846154
# Recall: 0.23880597014925373
# f1_score: 0.3440860215053763

# %% [markdown]
# #  Checking the model score of both training and testing data on different models

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC

model = [DecisionTreeClassifier,SVC,RandomForestClassifier,KNeighborsClassifier,AdaBoostClassifier]

for mod in model:
    reg = mod()
    reg = reg.fit(X_train,Y_train)
    print(mod ,'accuracy',reg.score(X_test,Y_test))
# Out:
# <class 'sklearn.tree._classes.DecisionTreeClassifier'> accuracy 0.8857677902621723
# <class 'sklearn.svm._classes.SVC'> accuracy 0.9194756554307116
# <class 'sklearn.ensemble._forest.RandomForestClassifier'> accuracy 0.9363295880149812
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'> accuracy 0.9063670411985019
# <class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'> accuracy 0.9082397003745318

# %% [markdown]
# #  Perform kfold, cross validation technique

# %%
from sklearn.model_selection import KFold,cross_val_score

models = []
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('RF', RandomForestClassifier()))
models.append(('SVM', SVC()))
models.append(('AdaBoost', AdaBoostClassifier()))



results = []
names = []
for name,model in models:
    kfold = KFold(n_splits=10)
    cv_result =cross_val_score(model,X_train,Y_train,cv=kfold)
    names.append(name)
    results.append(cv_result)
for i in range(len(names)):
    print(names[i],results[i].mean())
# Out:
# KNN 0.8921175025229257
# CART 0.8709863542626476
# RF 0.9132201307533675
# SVM 0.8944561449695054
# AdaBoost 0.860695011188627

# %%
results = []
names = []
for name,model in models:
    kfold = KFold(n_splits=10)
    cv_result =cross_val_score(model,X_test,Y_test,cv=kfold)
    names.append(name)
    results.append(cv_result)
for i in range(len(names)):
    print(names[i],results[i].mean())
# Out:
# KNN 0.9044374563242489
# CART 0.9136617749825298
# RF 0.9230957372466806
# SVM 0.8950384346610762
# AdaBoost 0.8894129979035641

# %%
from sklearn.ensemble import RandomForestClassifier
reg = RandomForestClassifier()
reg.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = reg.predict(X_test)

# %%
reg.score(X_train, Y_train)
# Out:
# 1.0

# %%
reg.score(X_test, Y_test)
# Out:
# 0.9419475655430711

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
min_samples_split = [2, 5, 10, 15, 100]
min_samples_leaf = [1, 2, 5, 10]

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

# %%
rf_random = RandomizedSearchCV(estimator = reg, 
                               param_distributions = random_grid,
                               scoring='neg_mean_squared_error', 
                               n_iter = 10, cv = 5,
                               verbose=2,
                               random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   2.0s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s remaining:    0.0s
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   2.0s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   3.1s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 1100,
#  'min_samples_split': 10,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': 15}

# %%
from sklearn.ensemble import RandomForestClassifier
new_reg = RandomForestClassifier(n_estimators= 1100,min_samples_split= 10,min_samples_leaf= 2,max_features='sqrt',max_depth=15)

# %%
new_reg.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(max_depth=15, max_features='sqrt', min_samples_leaf=2,
#                        min_samples_split=10, n_estimators=1100)

# %%
y_pred1 = new_reg.predict(X_test)
new_reg.score(X_train, Y_train)
# Out:
# 0.951688555347092

# %%
new_reg.score(X_test, Y_test)
# Out:
# 0.9363295880149812

# %% [markdown]
# # accuracy of the RandomForestClassifier is 93.63%

# %% [markdown]
# # using SVM to train model

# %% [markdown]
# # Performing hyperparameter tuning on SVM model

# %% [markdown]
# # keeping C=1 i.e;default

# %%
from sklearn.svm import SVC

log = SVC(C=1)
log.fit(X_train,Y_train)

y_pred = log.predict(X_test)

print("Log_test_score: ",log.score(X_test,Y_test))
print("Log_train_score: ",log.score(X_train,Y_train))
print("Accuracy with c=1: ",accuracy_score(Y_test,Y_pred))
# Out:
# Log_test_score:  0.9194756554307116
# Log_train_score:  0.9061913696060038
# Accuracy with c=1:  0.8857677902621723

# %% [markdown]
# # C=100

# %%
log1 = SVC(C=100)
log1.fit(X_train,Y_train)

Y_pred1 = log.predict(X_test)

print("Log_test_score: ",log1.score(X_test,Y_test))
print("Log_train_score: ",log1.score(X_train,Y_train))
print("Accuracy with c=100",accuracy_score(Y_test,Y_pred1))
# Out:
# Log_test_score:  0.9307116104868914
# Log_train_score:  0.9399624765478424
# Accuracy with c=100 0.9194756554307116

# %% [markdown]
# # keeping kernel=Linear and C=1

# %%
linear_svc=SVC(kernel='linear', C=1.0) 

# fit classifier to training set
linear_svc.fit(X_train,Y_train)

# make predictions on test set
Y_pred_lin=linear_svc.predict(X_test)

# compute and print accuracy score
print('Model accuracy score with linear kernel : {0:0.4f}'. format(accuracy_score(Y_test, Y_pred_lin)))
# Out:
# Model accuracy score with linear kernel : 0.8745

# %% [markdown]
# # keeping kernel=poly and C=1

# %%
poly_svc=SVC(kernel='poly', C=1.0) 

# fit classifier to training set
poly_svc.fit(X_train,Y_train)

# make predictions on test set
Y_pred_poly=poly_svc.predict(X_test)

# compute and print accuracy score
print('Model accuracy score with poly kernel : {0:0.4f}'. format(accuracy_score(Y_test, Y_pred_poly)))
# Out:
# Model accuracy score with poly kernel : 0.9157

# %% [markdown]
# # keeping kernel=sigmoid and C=1

# %%
sigmoid_svc=SVC(kernel='sigmoid', C=1.0) 

# fit classifier to training set
sigmoid_svc.fit(X_train,Y_train)

# make predictions on test set
Y_pred_sigmoid=sigmoid_svc.predict(X_test)

# compute and print accuracy score
print('Model accuracy score with poly kernel : {0:0.4f}'. format(accuracy_score(Y_test, Y_pred_sigmoid)))
# Out:
# Model accuracy score with poly kernel : 0.7715

# %% [markdown]
# # keeping kernel=linear and C=100

# %%
linear_svc=SVC(kernel='linear', C=100) 

# fit classifier to training set
linear_svc.fit(X_train,Y_train)

# make predictions on test set
Y_pred_lin=linear_svc.predict(X_test)

# compute and print accuracy score
print('Model accuracy score with linear kernel : {0:0.4f}'. format(accuracy_score(Y_test, Y_pred_lin)))
# Out:
# Model accuracy score with linear kernel : 0.8745

# %% [markdown]
# # keeping kernel=poly and C=100

# %%
poly_svc=SVC(kernel='poly', C=100) 

# fit classifier to training set
poly_svc.fit(X_train,Y_train)

# make predictions on test set
Y_pred_poly=poly_svc.predict(X_test)

# compute and print accuracy score
print('Model accuracy score with poly kernel : {0:0.4f}'. format(accuracy_score(Y_test, Y_pred_poly)))
# Out:
# Model accuracy score with poly kernel : 0.9270

# %% [markdown]
# # *Accuracy of C=100 with default "rbf" and "poly" comes out to be the highest from all *

# %% [markdown]
# # Report of C=100 kernel="poly"

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_test, Y_pred_poly))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       467
#            1       0.79      0.57      0.66        67
#
#     accuracy                           0.93       534
#    macro avg       0.87      0.77      0.81       534
# weighted avg       0.92      0.93      0.92       534

# %% [markdown]
# # Report of C=100 kernel="rbf"

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_test, Y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96       467
#            1       0.79      0.49      0.61        67
#
#     accuracy                           0.92       534
#    macro avg       0.86      0.74      0.78       534
# weighted avg       0.91      0.92      0.91       534
